# %%
# %sql
-- the assumption is that files are already in the cloud storage under volume /Volumes/dbs0808/landing/data
use catalog dbs0808;
create table if not exists bronze.customers_raw(
  CustomerID string,
  Country String
)
