# %%
# %sql
drop catalog dbs0808 cascade;
create catalog if not exists dbs0808;

use catalog dbs0808;
create schema if not exists landing;
create schema if not exists silver;
create schema if not exists gold;
create schema if not exists bronze;

create volume landing.data

# %%
dbutils.fs.mkdirs("/Volumes/dbs0808/landing/data/customers")
dbutils.fs.mkdirs("/Volumes/dbs0808/landing/data/products")
